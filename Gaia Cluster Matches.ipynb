# %%
from empca_residuals import *
import gaia_tools.load as gload
from gaia_tools import xmatch
import matplotlib.pyplot as plt
import os
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/lib/python2.7/site-packages/setuptools-18.7.1-py2.7.egg/pkg_resources/__init__.py:1266: UserWarning: /home/price-jones/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).

# %%
import astropy
filename='../clusterdata/aj485195t4_mrt.txt'
data= astropy.io.ascii.read(filename)
list(np.unique(data['Cluster']))
# Out:
# ['M107',
#  'M13',
#  'M15',
#  'M2',
#  'M3',
#  'M35',
#  'M5',
#  'M53',
#  'M67',
#  'M71',
#  'M92',
#  'N188',
#  'N2158',
#  'N2420',
#  'N4147',
#  'N5466',
#  'N6791',
#  'N6819',
#  'N7789',
#  'Pleiades']

# %%
tgas_cat= gload.tgas()

# %%
def plot_gaia_match():
    cluster = empca_residuals('apogee','clusters',maskFilter,ask=True)
    m1,m2,sep= xmatch.xmatch(cluster.matchingData,tgas_cat,colRA2='ra',colDec2='dec',epoch2=2015.)
    apogee_match = cluster.matchingData[m1]
    tgas_match = tgas_cat[m2]
    print 'Number of stars in TGAS: {0}'.format(len(m1))
    plt.figure(figsize=(10,7))
    plt.errorbar(tgas_match['pmra'],tgas_match['pmdec'],xerr=tgas_match['pmra_error'],yerr=tgas_match['pmdec_error'],fmt='o')
    plt.xlabel('Right ascension proper motion')
    plt.ylabel('Declination proper motion')
    plt.axes().set_aspect('equal', 'datalim')

# %%
#M107
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M107
# Data key: done
# Done getting filter information
# Total 0 of 18 stars missing
# Number of stars in TGAS: 0

# %%
#M13
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M13
# Data key: done
# Done getting filter information
# Number of stars in TGAS: 1

# %%
#M15
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M15
# Data key: done
# Done getting filter information
# Total 0 of 11 stars missing
# Number of stars in TGAS: 0

# %%
#M2
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M2
# Data key: done
# Done getting filter information
# Total 0 of 19 stars missing
# Number of stars in TGAS: 0

# %%
#M3
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M3
# Data key: done
# Done getting filter information
# Total 0 of 73 stars missing
# Number of stars in TGAS: 1

# %%
#M5
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M5
# Data key: done
# Done getting filter information
# Total 0 of 103 stars missing
# Number of stars in TGAS: 0

# %%
#M53
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M53
# Data key: done
# Done getting filter information
# Total 0 of 16 stars missing
# Number of stars in TGAS: 0

# %%
#M67
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M67
# Data key: done
# Done getting filter information
# Number of stars in TGAS: 9

# %%
#M92
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: M92
# Data key: done
# Done getting filter information
# Total 0 of 48 stars missing
# Number of stars in TGAS: 0

# %%
#N188
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: N188
# Data key: done
# Done getting filter information
# Total 0 of 5 stars missing
# Number of stars in TGAS: 1

# %%
#N2158
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: N2158
# Data key: done
# Done getting filter information
# Number of stars in TGAS: 0

# %%
#N2420,
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: N2420
# Data key: done
# Done getting filter information
# Total 0 of 9 stars missing
# Number of stars in TGAS: 1

# %%
#N6791
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: N6791
# Data key: done
# Done getting filter information
# Total 0 of 23 stars missing
# Number of stars in TGAS: 0

# %%
#N6819
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: N6819
# Data key: done
# Done getting filter information
# Number of stars in TGAS: 2

# %%
#N7789
plot_gaia_match()
# Out:
# Which data release? (Enter for 13): 12
# Type done at any prompt when finished
# Data key: CLUSTER
# Default is full range. Match or slice? m
# Match value: N7789
# Data key: done
# Done getting filter information
# Total 0 of 5 stars missing
# Number of stars in TGAS: 1
